# %% [markdown]
# <a href="https://colab.research.google.com/github/HendrikWulf/SDS110_labs/blob/main/Lab_3_Folium_Web_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Folium Web Mapping Lab

# %% [markdown]
# ## 1. Introduction
#
# In today’s world, sharing interactive web maps is an essential skill for spatial data scientists. In this hands-on lab, you will create and publish your own interactive web map using **Folium** and **GitHub Pages**. You will learn how to visualize spatial data in a notebook, export it as HTML, and publish it online for others to access.
#
# ---

# %% [markdown]
# ## 2. Learning Objectives
#
# By the end of this lab, you will be able to:
#
# - Set up a GitHub repository and activate GitHub Pages
# - Create interactive web maps using Folium
# - Add custom base maps, markers, lines, and polygons
# - Style maps and incorporate GeoJSON data
# - Publish and share your own web map online
#
# ---

# %% [markdown]
# ## 3. Setup GitHub
#
# 1. **Create a GitHub Account**
#    Follow [this guide](https://docs.github.com/en/get-started/start-your-journey/creating-an-account-on-github) to register.
#
# 2. **Enable 2FA (optional)**
#    Enable [Two-Factor Authentication](https://docs.github.com/en/authentication/securing-your-account-with-two-factor-authentication-2fa/configuring-two-factor-authentication) if possible.
#
# 3. **Create a New Repository**
#    Create a new GitHub repo with a README.md file.
#
# 4. **Copy the index file content**
#
#    Visit [this example page](https://github.com/HendrikWulf/SDS110_labs/tree/main) and open the file named index.html.
#
#    Copy the entire content of the index.html file.
#
# 5. **Add your own index html-file**
#
#    Go back to your own GitHub repository. Click the "Add file" symbol, then select "Create new file"
#
#    A file editor opens. Paste the copied content into the editor, give it the file name index.html, and click "Commit changes"
#
#
# ---

# %% [markdown]
# ## 4. Activate GitHub Pages
#
# GitHub Pages lets you publish static websites (built with HTML, CSS, or JavaScript) directly from your repository – for free. Let’s get your site online:
#
# 6. **Go to the Pages settings**
#    In your repository, click on the **Settings** tab. In the left sidebar, select **"Pages"**.
#
# 7. **Select the publishing source**
#    Under **"Build and Deployment"**, change the **Source** from `None` to `main` and click **"Save"**. This tells GitHub to use your main branch to generate the website.
#
# 8. **Wait for the magic**
#    It may take a few minutes for GitHub to build and publish your site.
#
# **Your website will be available at:**
# ```
# https://<your-username>.github.io/<repository-name>
# ```
#
# Congratulations! You've just published your first website using GitHub Pages.

# %% [markdown]
# ## Step 1: Create a Basic Web Map with Folium
#
# In this step, we'll create a simple interactive map using the folium library. We'll center the map on a location in Zurich, Switzerland, and set an appropriate zoom level to view a neighborhood-sized area.

# %%
# Import the folium library, which is used to create interactive web maps
import folium

# Create a folium Map object centered at latitude 47.396299 and longitude 8.549253
# The zoom level is set to 13 (reasonable city/neighborhood level)
# By default, the basemap used is OpenStreetMap
m = folium.Map(location=[47.396, 8.549], zoom_start=13)

# Display the map in a Jupyter/Colab notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5ad73c5ee93dc1568e21c875102b3f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5ad73c5ee93dc1568e21c875102b3f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5ad73c5ee93dc1568e21c875102b3f2 = L.map(
#                 &quot;map_b5ad73c5ee93dc1568e21c875102b3f2&quot;,
#                 {
#                     center: [47.396, 8.549],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd4b72e12354d5ab232bdc5372abc8ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd4b72e12354d5ab232bdc5372abc8ed.addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 2: Customize the Base Map
#
# A good base map provides spatial context and enhances the readability of your thematic data. In this step, you’ll explore how to change and customize base map styles in Folium to better suit the purpose and audience of your web map.
#
# Change the tile set:

# %%
import folium  # Import the folium library for creating interactive maps

# Create a Folium map object
m = folium.Map(
    location=[47.396, 8.549],
    tiles="OpenStreetMap",  # Other options are listed below
    zoom_start=13
)

# Available built-in basemap options in Folium:
# tiles="OpenStreetMap"         # Default OSM basemap
# tiles="Cartodb Positron"      # Light-colored basemap (good for overlays)
# tiles="Cartodb Dark_Matter"   # Dark-colored basemap

# You can also add custom tiles (like SwissTopo or others):
# tiles="https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png", attr="© OpenTopoMap (CC-BY-SA)",

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_560b3e6fe3796af82ece3caddc27ecae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_560b3e6fe3796af82ece3caddc27ecae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_560b3e6fe3796af82ece3caddc27ecae = L.map(
#                 &quot;map_560b3e6fe3796af82ece3caddc27ecae&quot;,
#                 {
#                     center: [47.396299, 8.549253],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb1939f7164fd4dae49c910ddf67acf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5eb1939f7164fd4dae49c910ddf67acf.addTo(map_560b3e6fe3796af82ece3caddc27ecae);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add SwissTopo as base map:

# %%
import folium

# Create a Folium map object
m = folium.Map(
    location=[47.396, 8.549],  # Set the initial map center coordinates (latitude, longitude) to Zurich, Switzerland
    tiles="https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg",  # Use SwissTopo map tiles as the basemap
    attr="© <a href='https://www.swisstopo.admin.ch/'>swisstopo</a>",  # Attribution for the SwissTopo map tiles
    zoom_start=13  # Set the initial zoom level
)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_107a450febc033f4700214ca59b17aca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_107a450febc033f4700214ca59b17aca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_107a450febc033f4700214ca59b17aca = L.map(
#                 &quot;map_107a450febc033f4700214ca59b17aca&quot;,
#                 {
#                     center: [47.396, 8.549],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_982bee8611a764f91e18a8e310a52ef5 = L.tileLayer(
#                 &quot;https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 \u003ca href=\u0027https://www.swisstopo.admin.ch/\u0027\u003eswisstopo\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_982bee8611a764f91e18a8e310a52ef5.addTo(map_107a450febc033f4700214ca59b17aca);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## Step 3: Add Markers, Lines, and Polygons
#
# To visualize and communicate spatial information effectively, you can add points, lines, and polygons to your map. In this step, you’ll learn how to represent locations, routes, and areas of interest using different geometry types in Folium.
#
# Add a point / marker:

# %%
# Create a Folium map object centered at specific coordinates
m = folium.Map(location=[47.365, 8.548], zoom_start=13)

# Add a marker to the map
# The marker is placed at the specified coordinates with a popup message
folium.Marker([47.365, 8.548], popup="Arthouse Piccadilly").add_to(m)

# Display the map with the added marker
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb9cde45580c6fa2a0431bda34a4212e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb9cde45580c6fa2a0431bda34a4212e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb9cde45580c6fa2a0431bda34a4212e = L.map(
#                 &quot;map_cb9cde45580c6fa2a0431bda34a4212e&quot;,
#                 {
#                     center: [47.365, 8.548],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06b7c7c453844375e31f7e8af32787da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_06b7c7c453844375e31f7e8af32787da.addTo(map_cb9cde45580c6fa2a0431bda34a4212e);
#
#
#             var marker_a9979fbf0e191192096d195ddb13c0c9 = L.marker(
#                 [47.365, 8.548],
#                 {
# }
#             ).addTo(map_cb9cde45580c6fa2a0431bda34a4212e);
#
#
#         var popup_13f2ce112cd8a847360c7b35b151ba17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c6d4eafd5a2fd9eb41d0192c2a50b34 = $(`&lt;div id=&quot;html_0c6d4eafd5a2fd9eb41d0192c2a50b34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arthouse Piccadilly&lt;/div&gt;`)[0];
#                 popup_13f2ce112cd8a847360c7b35b151ba17.setContent(html_0c6d4eafd5a2fd9eb41d0192c2a50b34);
#
#
#
#         marker_a9979fbf0e191192096d195ddb13c0c9.bindPopup(popup_13f2ce112cd8a847360c7b35b151ba17)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add a polyline:

# %%
# Define a list of two coordinate points (latitude, longitude) forming a line
line = [[47.349, 8.491], [47.389, 8.578]]

# Create a polyline (straight line) between the two points and add a popup label "Route"
folium.PolyLine(line, popup="Uetliberg to Zoo").add_to(m)

# Display the map with the added polyline
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5ad73c5ee93dc1568e21c875102b3f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5ad73c5ee93dc1568e21c875102b3f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5ad73c5ee93dc1568e21c875102b3f2 = L.map(
#                 &quot;map_b5ad73c5ee93dc1568e21c875102b3f2&quot;,
#                 {
#                     center: [47.396, 8.549],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd4b72e12354d5ab232bdc5372abc8ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd4b72e12354d5ab232bdc5372abc8ed.addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#             tile_layer_cd4b72e12354d5ab232bdc5372abc8ed.addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#             var poly_line_5751e8170708c21b58f92a209fba2489 = L.polyline(
#                 [[47.349, 8.491], [47.389, 8.578]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#         var popup_f2b9431bf73fcd13adb6c2178c0d19e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1fab76cba5a3a5567cb1f7d2fd0035b = $(`&lt;div id=&quot;html_c1fab76cba5a3a5567cb1f7d2fd0035b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;This distance from Uetliberg to Zoo is about 8 km.&lt;/div&gt;`)[0];
#                 popup_f2b9431bf73fcd13adb6c2178c0d19e6.setContent(html_c1fab76cba5a3a5567cb1f7d2fd0035b);
#
#
#
#         poly_line_5751e8170708c21b58f92a209fba2489.bindPopup(popup_f2b9431bf73fcd13adb6c2178c0d19e6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add a polygon:

# %%
# Define a list of coordinate points (latitude, longitude) that form the vertices of a polygon
polygon = [[47.400, 8.541], [47.399, 8.553], [47.393, 8.552], [47.396, 8.541]]

# Create a polygon from the coordinate list and add a popup label "Campus Irchel Area"
folium.Polygon(polygon, popup="Campus Irchel Area").add_to(m)

# Display the map with the polygon added
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5ad73c5ee93dc1568e21c875102b3f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5ad73c5ee93dc1568e21c875102b3f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5ad73c5ee93dc1568e21c875102b3f2 = L.map(
#                 &quot;map_b5ad73c5ee93dc1568e21c875102b3f2&quot;,
#                 {
#                     center: [47.396, 8.549],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd4b72e12354d5ab232bdc5372abc8ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd4b72e12354d5ab232bdc5372abc8ed.addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#             tile_layer_cd4b72e12354d5ab232bdc5372abc8ed.addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#             var poly_line_5751e8170708c21b58f92a209fba2489 = L.polyline(
#                 [[47.349, 8.491], [47.389, 8.578]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#         var popup_f2b9431bf73fcd13adb6c2178c0d19e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1fab76cba5a3a5567cb1f7d2fd0035b = $(`&lt;div id=&quot;html_c1fab76cba5a3a5567cb1f7d2fd0035b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;This distance from Uetliberg to Zoo is about 8 km.&lt;/div&gt;`)[0];
#                 popup_f2b9431bf73fcd13adb6c2178c0d19e6.setContent(html_c1fab76cba5a3a5567cb1f7d2fd0035b);
#
#
#
#         poly_line_5751e8170708c21b58f92a209fba2489.bindPopup(popup_f2b9431bf73fcd13adb6c2178c0d19e6)
#         ;
#
#
#
#
#             tile_layer_cd4b72e12354d5ab232bdc5372abc8ed.addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#             var polygon_8e3dc632941071f9847f475e55781c7a = L.polygon(
#                 [[47.4, 8.541], [47.399, 8.553], [47.393, 8.552], [47.396, 8.541]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b5ad73c5ee93dc1568e21c875102b3f2);
#
#
#         var popup_084e7b07efd2771de8873af27b63cef8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b493c91f59347dc850829e04a65f18df = $(`&lt;div id=&quot;html_b493c91f59347dc850829e04a65f18df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Campus Irchel Area&lt;/div&gt;`)[0];
#                 popup_084e7b07efd2771de8873af27b63cef8.setContent(html_b493c91f59347dc850829e04a65f18df);
#
#
#
#         polygon_8e3dc632941071f9847f475e55781c7a.bindPopup(popup_084e7b07efd2771de8873af27b63cef8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## Step 4: Group Layers with LayerControl
#
# When working with multiple datasets or map styles, it's useful to organize your layers so users can toggle them on or off. In this step, you'll learn how to group and manage map layers using LayerControl to create more interactive and user-friendly web maps.

# %%
# Create a base map centered at specified coordinates, with no default basemap (tiles=None)
m = folium.Map(location=[47.36635, 8.54136], tiles=None, zoom_start=13)

# Add OpenStreetMap as a tile layer (default basemap)
folium.TileLayer("OpenStreetMap").add_to(m)

# Add a custom tile layer from SwissTopo with imagery (WMTS service)
folium.TileLayer(
    tiles="https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg",  # Swiss aerial imagery
    attr="© swisstopo",   # Attribution required by SwissTopo
    name="SwissTopo",     # Name shown in the layer control
    show=False            # Do not show this layer by default
).add_to(m)

# Add a layer control (upper right by default) so users can switch between the basemaps
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bbda4112db0fa184f9503e82bb4a36f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bbda4112db0fa184f9503e82bb4a36f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bbda4112db0fa184f9503e82bb4a36f = L.map(
#                 &quot;map_4bbda4112db0fa184f9503e82bb4a36f&quot;,
#                 {
#                     center: [47.36635, 8.54136],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed6f62aef9eaa9336cc18706278f59df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed6f62aef9eaa9336cc18706278f59df.addTo(map_4bbda4112db0fa184f9503e82bb4a36f);
#
#
#             var tile_layer_5f3e458d5d432e3225ae24356e1b0c9f = L.tileLayer(
#                 &quot;https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 swisstopo&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var layer_control_6c4c030de25a2471c806eef79f9b47bd_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ed6f62aef9eaa9336cc18706278f59df,
#                     &quot;SwissTopo&quot; : tile_layer_5f3e458d5d432e3225ae24356e1b0c9f,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_6c4c030de25a2471c806eef79f9b47bd = L.control.layers(
#                 layer_control_6c4c030de25a2471c806eef79f9b47bd_layers.base_layers,
#                 layer_control_6c4c030de25a2471c806eef79f9b47bd_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_4bbda4112db0fa184f9503e82bb4a36f);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Add GeoJSON Data
# You can also load a GeoJSON file containing multiple geometries and display them as markers on the map. In this example, the points represent drinking fountains in Zurich.
#
# **Note:** Before adding the data to the map, make sure to convert it to the correct coordinate reference system (WGS 84, EPSG:4326), which is required by Folium for accurate visualization.

# %%
import folium
import geopandas as gpd

# 1. Create/load your Folium map (ensure it's not redefined later)
m = folium.Map(location=[47.365, 8.548], zoom_start=13)

# 2. Load GeoJSON data
url = "https://raw.githubusercontent.com/HendrikWulf/SDS110_labs/main/drinking_water_zurich_epsg2056.geojson"
drinking_fountain = gpd.read_file(url).to_crs(epsg=4326)

# 3. Add markers (using the same map object 'm')
for index, row in drinking_fountain.iterrows():
    coordinates = row['geometry'].centroid.coords[0]
    folium.Marker(location=[coordinates[1], coordinates[0]], popup=row['name']).add_to(m)

# 4. Display the map (with markers added)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28aa1ade8337f4d4ab2f6ab44e514f33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28aa1ade8337f4d4ab2f6ab44e514f33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28aa1ade8337f4d4ab2f6ab44e514f33 = L.map(
#                 &quot;map_28aa1ade8337f4d4ab2f6ab44e514f33&quot;,
#                 {
#                     center: [47.396299, 8.549253],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43e2a81045f644379fe74058c12b4746 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43e2a81045f644379fe74058c12b4746.addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_52aa6e377c9f54f42d74958a9c63922e = L.marker(
#                 [47.41353431017447, 8.541278108379558],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#         var popup_2c0158bb072fd11dc8df105d237145f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_054753f90ae6e99d16c34db3ab43a209 = $(`&lt;div id=&quot;html_054753f90ae6e99d16c34db3ab43a209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Notwasserbrunnen&lt;/div&gt;`)[0];
#                 popup_2c0158bb072fd11dc8df105d237145f3.setContent(html_054753f90ae6e99d16c34db3ab43a209);
#
#
#
#         marker_52aa6e377c9f54f42d74958a9c63922e.bindPopup(popup_2c0158bb072fd11dc8df105d237145f3)
#         ;
#
#
#
#
#             var marker_b5cec26ea88b48b752b9043748f01e3c = L.marker(
#                 [47.402830010183635, 8.49994040833819],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#         var popup_1172174a8b469d31b59bcff789d53745 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c9ecd796643471ab2c678302664f9e4 = $(`&lt;div id=&quot;html_0c9ecd796643471ab2c678302664f9e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tränkbrunnen Höngg&lt;/div&gt;`)[0];
#                 popup_1172174a8b469d31b59bcff789d53745.setContent(html_0c9ecd796643471ab2c678302664f9e4);
#
#
#
#         marker_b5cec26ea88b48b752b9043748f01e3c.bindPopup(popup_1172174a8b469d31b59bcff789d53745)
#         ;
#
#
#
#
#             var marker_f3506ae5610c618be485c4ca22cb3b21 = L.marker(
#                 [47.40216371018733, 8.49944180833675],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_4af79c7ce7030258175e36e38fd9a916 = L.marker(
#                 [47.40729091017536, 8.550476408394264],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_6935b875d327078a4a752d18b03c4428 = L.marker(
#                 [47.405301110180424, 8.503773708339574],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_fdd156b5128b0acbc801977d8e9f38cd = L.marker(
#                 [47.40929161018714, 8.49485070834046],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#         var popup_26b97fe81c25f7913f2123942970e80f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc75f46d7619538308e3740a042e5815 = $(`&lt;div id=&quot;html_cc75f46d7619538308e3740a042e5815&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brunnen zur Eingemeidung&lt;/div&gt;`)[0];
#                 popup_26b97fe81c25f7913f2123942970e80f.setContent(html_cc75f46d7619538308e3740a042e5815);
#
#
#
#         marker_fdd156b5128b0acbc801977d8e9f38cd.bindPopup(popup_26b97fe81c25f7913f2123942970e80f)
#         ;
#
#
#
#
#             var marker_95e8b7bc520b882cd65e748408408974 = L.marker(
#                 [47.33748811015381, 8.524711108386514],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_43e0f3b401b27c35f0636ddf7bb5b964 = L.marker(
#                 [47.34089691015174, 8.532752108400429],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_78544c56cb817bd82425708935e2bd63 = L.marker(
#                 [47.34053491015467, 8.532639108387853],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_b6cd2d052e65b4a55c07908d0506bf2e = L.marker(
#                 [47.32467241015497, 8.523118708387415],
#                 {
# }
#             ).addTo(map_28aa1ade8337f4d4ab2f6ab44e514f33);
#
#
#             var marker_710115df7eb5b76642cfbf1874fcb077 = L.marker(
#                 [47.336427710150964, 8.533277708400979],

# %% [markdown]
# ## Step 6: Export and add your map to Github
# Export the map as as an interactive HTML file:

# %%
# Save the current folium map object (m) as an interactive HTML file named "map_1.html"
# You can find it and download it under "Files"
# You can also open this file in any web browser to view the map outside of the notebook environment
m.save("map_1.html")

# %% [markdown]
# To publish your map online follow these steps:
#
# 1. **Find your HTML file** (e.g., `map_1.html`) in your Colab file panel.
# 2. **Download the HTML file** to your local computer.
# 3. **Open the file** in your web browser to view the interactive map.
# 4. **Open the same file in a text editor** (e.g., VS Code, Atom, or Notepad).
# 5. **Copy the HTML code**, then go to your GitHub repository and open your previously created `index.html` file.
# 6. **Paste the HTML code** into the `index.html`, adjust the text from the previous headings and save it (commit the changes).
#
# After a few minutes, your own web map will be update with the additional map!
#
# **Your map online website:**
# ```
# https://<your-username>.github.io/<repository-name>
# ```
#
# ---
