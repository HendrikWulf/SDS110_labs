# %% [markdown]
# <a href="https://colab.research.google.com/github/HendrikWulf/SDS110_labs/blob/main/Lab_3_Folium_Web_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Folium Web Mapping Lab

# %% [markdown]
# ## 1. Introduction
#
# In today’s world, sharing interactive web maps is an essential skill for spatial data scientists. In this hands-on lab, you will create and publish your own interactive web map using **Folium** and **GitHub Pages**. You will learn how to visualize spatial data in a notebook, export it as HTML, and publish it online for others to access.
#
# ---

# %% [markdown]
# ## 2. Learning Objectives
#
# By the end of this lab, you will be able to:
#
# - Set up a GitHub repository and activate GitHub Pages
# - Create interactive web maps using Folium
# - Add custom base maps, markers, lines, and polygons
# - Style maps and incorporate GeoJSON data
# - Publish and share your own web map online
#
# ---

# %% [markdown]
# ## 3. Setup GitHub
#
# 1. **Create a GitHub Account**
#    Follow [this guide](https://docs.github.com/en/get-started/start-your-journey/creating-an-account-on-github) to register.
#
# 2. **Enable 2FA (optional)**
#    Enable [Two-Factor Authentication](https://docs.github.com/en/authentication/securing-your-account-with-two-factor-authentication-2fa/configuring-two-factor-authentication) if possible.
#
# 3. **Create a New Repository**
#    Create a new GitHub repo with a README.md file.
#
# 4. **Copy the index file content**
#
#    Visit [this example page](https://github.com/HendrikWulf/SDS110_labs/tree/main) and open the file named index.html.
#
#    Copy the entire content of the index.html file.
#
# 5. **Add your own index html-file**
#
#    Go back to your own GitHub repository. Click the "Add file" symbol, then select "Create new file"
#
#    A file editor opens. Paste the copied content into the editor, give it the file name index.html, and click "Commit changes"
#
#
# ---

# %% [markdown]
# ## 4. Activate GitHub Pages
#
# GitHub Pages lets you publish static websites (built with HTML, CSS, or JavaScript) directly from your repository – for free. Let’s get your site online:
#
# 6. **Go to the Pages settings**
#    In your repository, click on the **Settings** tab. In the left sidebar, select **"Pages"**.
#
# 7. **Select the publishing source**
#    Under **"Build and Deployment"**, change the **Source** from `None` to `main` and click **"Save"**. This tells GitHub to use your main branch to generate the website.
#
# 8. **Wait for the magic**
#    It may take a few minutes for GitHub to build and publish your site.
#
# **Your website will be available at:**
# ```
# https://<your-username>.github.io/<repository-name>
# ```
#
# Congratulations! You've just published your first website using GitHub Pages.

# %% [markdown]
# ## Step 1: Create a Basic Web Map with Folium
#
# In this step, we'll create a simple interactive map using the folium library. We'll center the map on a location in Zurich, Switzerland, and set an appropriate zoom level to view a neighborhood-sized area.

# %%
# Import the folium library, which is used to create interactive web maps
import folium

# Create a folium Map object centered at latitude 47.396299 and longitude 8.549253
# The zoom level is set to 13 (reasonable city/neighborhood level)
# By default, the basemap used is OpenStreetMap
m = folium.Map(location=[47.396, 8.549], zoom_start=13)

# Display the map in a Jupyter/Colab notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfef5bc55f98a421539b541c74e243cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfef5bc55f98a421539b541c74e243cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfef5bc55f98a421539b541c74e243cc = L.map(
#                 &quot;map_dfef5bc55f98a421539b541c74e243cc&quot;,
#                 {
#                     center: [47.396, 8.549],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfc9f472265465d2aaadefc16586ae71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cfc9f472265465d2aaadefc16586ae71.addTo(map_dfef5bc55f98a421539b541c74e243cc);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 2: Customize the Base Map
#
# A good base map provides spatial context and enhances the readability of your thematic data. In this step, you’ll explore how to change and customize base map styles in Folium to better suit the purpose and audience of your web map.
#
# Change the tile set:

# %%
import folium  # Import the folium library for creating interactive maps

# Create a Folium map object
m = folium.Map(
    location=[47.396, 8.549],
    tiles="OpenStreetMap",  # Other options are listed below
    zoom_start=13
)

# Available built-in basemap options in Folium:
# tiles="OpenStreetMap"         # Default OSM basemap
# tiles="Cartodb Positron"      # Light-colored basemap (good for overlays)
# tiles="Cartodb Dark_Matter"   # Dark-colored basemap

# You can also add custom tiles (like SwissTopo or others):
# tiles="https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png", attr="© OpenTopoMap (CC-BY-SA)",

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebb5203b04be1162d0160c4858cf7371 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebb5203b04be1162d0160c4858cf7371&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebb5203b04be1162d0160c4858cf7371 = L.map(
#                 &quot;map_ebb5203b04be1162d0160c4858cf7371&quot;,
#                 {
#                     center: [47.396, 8.549],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75dbb061f71b9cbde6996d719ee8eaf8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75dbb061f71b9cbde6996d719ee8eaf8.addTo(map_ebb5203b04be1162d0160c4858cf7371);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add SwissTopo as base map:

# %%
import folium

# Create a Folium map object
m = folium.Map(
    location=[47.396, 8.549],  # Set the initial map center coordinates (latitude, longitude) to Zurich, Switzerland
    tiles="https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg",  # Use SwissTopo map tiles as the basemap
    attr="© <a href='https://www.swisstopo.admin.ch/'>swisstopo</a>",  # Attribution for the SwissTopo map tiles
    zoom_start=13  # Set the initial zoom level
)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29eb6738612b79edc68a69b8e374f657 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29eb6738612b79edc68a69b8e374f657&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29eb6738612b79edc68a69b8e374f657 = L.map(
#                 &quot;map_29eb6738612b79edc68a69b8e374f657&quot;,
#                 {
#                     center: [47.396, 8.549],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc3321cf28c38a0eb86f79cb03e7d283 = L.tileLayer(
#                 &quot;https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 \u003ca href=\u0027https://www.swisstopo.admin.ch/\u0027\u003eswisstopo\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc3321cf28c38a0eb86f79cb03e7d283.addTo(map_29eb6738612b79edc68a69b8e374f657);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## Step 3: Add Markers, Lines, and Polygons
#
# To visualize and communicate spatial information effectively, you can add points, lines, and polygons to your map. In this step, you’ll learn how to represent locations, routes, and areas of interest using different geometry types in Folium.
#
# Add a point / marker:

# %%
# Create a Folium map object centered at specific coordinates
m = folium.Map(location=[47.365, 8.548], zoom_start=13)

# Add a marker to the map
# The marker is placed at the specified coordinates with a popup message
folium.Marker([47.365, 8.548], popup="Arthouse Piccadilly").add_to(m)

# Display the map with the added marker
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0efd61b3f29e85142145d7369eb6d66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0efd61b3f29e85142145d7369eb6d66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0efd61b3f29e85142145d7369eb6d66 = L.map(
#                 &quot;map_d0efd61b3f29e85142145d7369eb6d66&quot;,
#                 {
#                     center: [47.365, 8.548],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0e18169f30d18f39c98a2ddbed0ee1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0e18169f30d18f39c98a2ddbed0ee1a.addTo(map_d0efd61b3f29e85142145d7369eb6d66);
#
#
#             var marker_9dcc5af5047562e2b71a46f22c662c5f = L.marker(
#                 [47.365, 8.548],
#                 {
# }
#             ).addTo(map_d0efd61b3f29e85142145d7369eb6d66);
#
#
#         var popup_e30228ea667ca72787076a6e4d1527f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae18f7420e6261713f6749945a3825cb = $(`&lt;div id=&quot;html_ae18f7420e6261713f6749945a3825cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arthouse Piccadilly&lt;/div&gt;`)[0];
#                 popup_e30228ea667ca72787076a6e4d1527f7.setContent(html_ae18f7420e6261713f6749945a3825cb);
#
#
#
#         marker_9dcc5af5047562e2b71a46f22c662c5f.bindPopup(popup_e30228ea667ca72787076a6e4d1527f7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add a polyline:

# %%
# Define a list of two coordinate points (latitude, longitude) forming a line
line = [[47.349, 8.491], [47.389, 8.578]]

# Create a polyline (straight line) between the two points and add a popup label "Route"
folium.PolyLine(line, popup="Uetliberg to Zoo").add_to(m)

# Display the map with the added polyline
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0efd61b3f29e85142145d7369eb6d66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0efd61b3f29e85142145d7369eb6d66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0efd61b3f29e85142145d7369eb6d66 = L.map(
#                 &quot;map_d0efd61b3f29e85142145d7369eb6d66&quot;,
#                 {
#                     center: [47.365, 8.548],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0e18169f30d18f39c98a2ddbed0ee1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0e18169f30d18f39c98a2ddbed0ee1a.addTo(map_d0efd61b3f29e85142145d7369eb6d66);
#
#
#             var marker_9dcc5af5047562e2b71a46f22c662c5f = L.marker(
#                 [47.365, 8.548],
#                 {
# }
#             ).addTo(map_d0efd61b3f29e85142145d7369eb6d66);
#
#
#         var popup_e30228ea667ca72787076a6e4d1527f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae18f7420e6261713f6749945a3825cb = $(`&lt;div id=&quot;html_ae18f7420e6261713f6749945a3825cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arthouse Piccadilly&lt;/div&gt;`)[0];
#                 popup_e30228ea667ca72787076a6e4d1527f7.setContent(html_ae18f7420e6261713f6749945a3825cb);
#
#
#
#         marker_9dcc5af5047562e2b71a46f22c662c5f.bindPopup(popup_e30228ea667ca72787076a6e4d1527f7)
#         ;
#
#
#
#
#             tile_layer_e0e18169f30d18f39c98a2ddbed0ee1a.addTo(map_d0efd61b3f29e85142145d7369eb6d66);
#
#
#             var poly_line_a68a65590b2e3655edf65073d4e76062 = L.polyline(
#                 [[47.349, 8.491], [47.389, 8.578]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0efd61b3f29e85142145d7369eb6d66);
#
#
#         var popup_7ec03a16e9231e7d2697d5d94ea701ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dccc957365d4047b351dbd96cc5c679 = $(`&lt;div id=&quot;html_5dccc957365d4047b351dbd96cc5c679&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uetliberg to Zoo&lt;/div&gt;`)[0];
#                 popup_7ec03a16e9231e7d2697d5d94ea701ee.setContent(html_5dccc957365d4047b351dbd96cc5c679);
#
#
#
#         poly_line_a68a65590b2e3655edf65073d4e76062.bindPopup(popup_7ec03a16e9231e7d2697d5d94ea701ee)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add a polygon:

# %%
# Define a list of coordinate points (latitude, longitude) that form the vertices of a polygon
polygon = [[47.400, 8.541], [47.399, 8.553], [47.393, 8.552], [47.396, 8.541]]

# Create a polygon from the coordinate list and add a popup label "Campus Irchel Area"
folium.Polygon(polygon, popup="Campus Irchel Area").add_to(m)

# Display the map with the polygon added
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14d92b7b6c03200d3b39f724ec45b09e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14d92b7b6c03200d3b39f724ec45b09e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14d92b7b6c03200d3b39f724ec45b09e = L.map(
#                 &quot;map_14d92b7b6c03200d3b39f724ec45b09e&quot;,
#                 {
#                     center: [47.36635, 8.54136],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc20038166985b2f6bf4206563d53140 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc20038166985b2f6bf4206563d53140.addTo(map_14d92b7b6c03200d3b39f724ec45b09e);
#
#
#             var tile_layer_53f7cc37c004da5614d71f432d1531e8 = L.tileLayer(
#                 &quot;https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 swisstopo&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var layer_control_0f386c73855e1f3e66b49079a1fc1d38_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_dc20038166985b2f6bf4206563d53140,
#                     &quot;SwissTopo&quot; : tile_layer_53f7cc37c004da5614d71f432d1531e8,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_0f386c73855e1f3e66b49079a1fc1d38 = L.control.layers(
#                 layer_control_0f386c73855e1f3e66b49079a1fc1d38_layers.base_layers,
#                 layer_control_0f386c73855e1f3e66b49079a1fc1d38_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_14d92b7b6c03200d3b39f724ec45b09e);
#
#
#
#             tile_layer_dc20038166985b2f6bf4206563d53140.addTo(map_14d92b7b6c03200d3b39f724ec45b09e);
#
#
#             var polygon_3e941505cb9767911f1217ebc71a0dc1 = L.polygon(
#                 [[47.4, 8.541], [47.399, 8.553], [47.393, 8.552], [47.396, 8.541]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_14d92b7b6c03200d3b39f724ec45b09e);
#
#
#         var popup_f29647c9858e648af6675307aad11c32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ce08d07d9ad582567444f183313fad5 = $(`&lt;div id=&quot;html_2ce08d07d9ad582567444f183313fad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Campus Irchel Area&lt;/div&gt;`)[0];
#                 popup_f29647c9858e648af6675307aad11c32.setContent(html_2ce08d07d9ad582567444f183313fad5);
#
#
#
#         polygon_3e941505cb9767911f1217ebc71a0dc1.bindPopup(popup_f29647c9858e648af6675307aad11c32)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---

# %% [markdown]
# ## Step 4: Group Layers with LayerControl
#
# When working with multiple datasets or map styles, it's useful to organize your layers so users can toggle them on or off. In this step, you'll learn how to group and manage map layers using LayerControl to create more interactive and user-friendly web maps.

# %%
# Create a base map centered at specified coordinates, with no default basemap (tiles=None)
m = folium.Map(location=[47.36635, 8.54136], tiles=None, zoom_start=13)

# Add OpenStreetMap as a tile layer (default basemap)
folium.TileLayer("OpenStreetMap").add_to(m)

# Add a custom tile layer from SwissTopo with imagery (WMTS service)
folium.TileLayer(
    tiles="https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg",  # Swiss aerial imagery
    attr="© swisstopo",   # Attribution required by SwissTopo
    name="SwissTopo",     # Name shown in the layer control
    show=False            # Do not show this layer by default
).add_to(m)

# Add a layer control (upper right by default) so users can switch between the basemaps
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f36b8e13f8b0fea1c93cd388c69e8d08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f36b8e13f8b0fea1c93cd388c69e8d08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f36b8e13f8b0fea1c93cd388c69e8d08 = L.map(
#                 &quot;map_f36b8e13f8b0fea1c93cd388c69e8d08&quot;,
#                 {
#                     center: [47.36635, 8.54136],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a0f5bdfaf3a9576cb5e16c605273873 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a0f5bdfaf3a9576cb5e16c605273873.addTo(map_f36b8e13f8b0fea1c93cd388c69e8d08);
#
#
#             var tile_layer_4d18a0e5dc1eb7b800d4d6cf746e9e5c = L.tileLayer(
#                 &quot;https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{z}/{x}/{y}.jpeg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 swisstopo&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var layer_control_00eb036f84ccbc7c56d932f11bb3746c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5a0f5bdfaf3a9576cb5e16c605273873,
#                     &quot;SwissTopo&quot; : tile_layer_4d18a0e5dc1eb7b800d4d6cf746e9e5c,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_00eb036f84ccbc7c56d932f11bb3746c = L.control.layers(
#                 layer_control_00eb036f84ccbc7c56d932f11bb3746c_layers.base_layers,
#                 layer_control_00eb036f84ccbc7c56d932f11bb3746c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f36b8e13f8b0fea1c93cd388c69e8d08);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 5: Add GeoJSON Data
# You can also load a GeoJSON file containing multiple geometries and display them as markers on the map. In this example, the points represent drinking fountains in Zurich.
#
# **Note:** Before adding the data to the map, make sure to convert it to the correct coordinate reference system (WGS 84, EPSG:4326), which is required by Folium for accurate visualization.

# %%
import folium
import geopandas as gpd

# 1. Create/load your Folium map (ensure it's not redefined later)
m = folium.Map(location=[47.365, 8.548], zoom_start=13)

# 2. Load GeoJSON data
url = "https://raw.githubusercontent.com/HendrikWulf/SDS110_labs/main/drinking_water_zurich_epsg2056.geojson"
drinking_fountain = gpd.read_file(url).to_crs(epsg=4326)

# 3. Add markers (using the same map object 'm')
for index, row in drinking_fountain.iterrows():
    coordinates = row['geometry'].centroid.coords[0]
    folium.Marker(location=[coordinates[1], coordinates[0]], popup=row['name']).add_to(m)

# 4. Display the map (with markers added)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62c4e495464096b7d2df7468e490397e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62c4e495464096b7d2df7468e490397e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62c4e495464096b7d2df7468e490397e = L.map(
#                 &quot;map_62c4e495464096b7d2df7468e490397e&quot;,
#                 {
#                     center: [47.365, 8.548],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d50caf11a4eaa819410aa1c1b23d2594 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d50caf11a4eaa819410aa1c1b23d2594.addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#             var marker_94fd92755fcce859df344a18f9f46e7e = L.marker(
#                 [47.41353431017447, 8.541278108379558],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#         var popup_cabf357813b2e988a927034540be9036 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2ec0ca2408e2af37fea517a7cf592be = $(`&lt;div id=&quot;html_f2ec0ca2408e2af37fea517a7cf592be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Notwasserbrunnen&lt;/div&gt;`)[0];
#                 popup_cabf357813b2e988a927034540be9036.setContent(html_f2ec0ca2408e2af37fea517a7cf592be);
#
#
#
#         marker_94fd92755fcce859df344a18f9f46e7e.bindPopup(popup_cabf357813b2e988a927034540be9036)
#         ;
#
#
#
#
#             var marker_40484f89abef815b6d4a9d7be83e59e5 = L.marker(
#                 [47.402830010183635, 8.49994040833819],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#         var popup_442dd199b77f4cea48cd236b62d79a2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da8f7fc83d7da6b8403345d4b3cde714 = $(`&lt;div id=&quot;html_da8f7fc83d7da6b8403345d4b3cde714&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tränkbrunnen Höngg&lt;/div&gt;`)[0];
#                 popup_442dd199b77f4cea48cd236b62d79a2a.setContent(html_da8f7fc83d7da6b8403345d4b3cde714);
#
#
#
#         marker_40484f89abef815b6d4a9d7be83e59e5.bindPopup(popup_442dd199b77f4cea48cd236b62d79a2a)
#         ;
#
#
#
#
#             var marker_2b02921bd1f47b8c20dbb60b4c3e58ff = L.marker(
#                 [47.40216371018733, 8.49944180833675],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#             var marker_150755770b8504550e711832f4fe9a1e = L.marker(
#                 [47.40729091017536, 8.550476408394264],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#             var marker_58d27d477d44ddf6e6562714e48073ef = L.marker(
#                 [47.405301110180424, 8.503773708339574],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#             var marker_269ed2d9fcf1e025a4701debec9269f4 = L.marker(
#                 [47.40929161018714, 8.49485070834046],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#         var popup_269e078c192d04ab18495bdc3ab0f391 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c06c2512006fc2e9c3e58f923bec8391 = $(`&lt;div id=&quot;html_c06c2512006fc2e9c3e58f923bec8391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brunnen zur Eingemeidung&lt;/div&gt;`)[0];
#                 popup_269e078c192d04ab18495bdc3ab0f391.setContent(html_c06c2512006fc2e9c3e58f923bec8391);
#
#
#
#         marker_269ed2d9fcf1e025a4701debec9269f4.bindPopup(popup_269e078c192d04ab18495bdc3ab0f391)
#         ;
#
#
#
#
#             var marker_b76e302b1826169888dc2a91586a042b = L.marker(
#                 [47.33748811015381, 8.524711108386514],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#             var marker_bc65b4e52989e5799767cc4521dd457b = L.marker(
#                 [47.34089691015174, 8.532752108400429],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#             var marker_f2ab790246be336e29e0520bf4224677 = L.marker(
#                 [47.34053491015467, 8.532639108387853],
#                 {
# }
#             ).addTo(map_62c4e495464096b7d2df7468e490397e);
#
#
#             var marker_922bc3849270c3a03b921a8c6e97f6d5 = L.marker(
#                 [47.32467241015497, 8.523118708387415],

# %% [markdown]
# ## Step 6: Add Point Clustering
#
# When visualizing many point features, individual markers can quickly overlap and clutter the map.
# Point clustering groups nearby points into a single cluster marker, showing the number of features it represents. As you zoom in, the clusters expand to reveal individual points.
#
# This approach improves both map readability and performance—especially when displaying dense datasets like drinking fountains across Zurich.

# %%
import folium
import geopandas as gpd
from folium.plugins import MarkerCluster  # <-- clustering

# 1) Base map
m = folium.Map(location=[47.365, 8.548], zoom_start=13)

# 2) Load data and convert to WGS84
url = "https://raw.githubusercontent.com/HendrikWulf/SDS110_labs/main/drinking_water_zurich_epsg2056.geojson"
drinking_fountain = gpd.read_file(url).to_crs(epsg=4326)

# 3) Add a cluster group
cluster = MarkerCluster(name="Drinking fountains").add_to(m)

# 4) Add markers into the cluster
for _, row in drinking_fountain.iterrows():
    lon, lat = row.geometry.centroid.x, row.geometry.centroid.y
    folium.Marker([lat, lon], popup=row.get("name", "unknown")).add_to(cluster)

# Optional: Fast clustering for very large datasets
# from folium.plugins import FastMarkerCluster
# coords = [[geom.y, geom.x] for geom in drinking_fountain.geometry.centroid]
# FastMarkerCluster(coords, name="Drinking fountains (fast)").add_to(m)

# 5) Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c558661d47d5e929f83c30c14f33d985 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c558661d47d5e929f83c30c14f33d985&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c558661d47d5e929f83c30c14f33d985 = L.map(
#                 &quot;map_c558661d47d5e929f83c30c14f33d985&quot;,
#                 {
#                     center: [47.365, 8.548],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1d054dd41664fccddee1691dd925549 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1d054dd41664fccddee1691dd925549.addTo(map_c558661d47d5e929f83c30c14f33d985);
#
#
#             var marker_cluster_84d835bd9c993a0cb8dc8c537dbf6723 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_b7970671ab8a45375b6ec3c3bb3a0c1d = L.marker(
#                 [47.41353431017447, 8.541278108379558],
#                 {
# }
#             ).addTo(marker_cluster_84d835bd9c993a0cb8dc8c537dbf6723);
#
#
#         var popup_91fc0615c70b62b2dc3c25af7b84982c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a94c19d7622436d76fbf4afa3faff943 = $(`&lt;div id=&quot;html_a94c19d7622436d76fbf4afa3faff943&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Notwasserbrunnen&lt;/div&gt;`)[0];
#                 popup_91fc0615c70b62b2dc3c25af7b84982c.setContent(html_a94c19d7622436d76fbf4afa3faff943);
#
#
#
#         marker_b7970671ab8a45375b6ec3c3bb3a0c1d.bindPopup(popup_91fc0615c70b62b2dc3c25af7b84982c)
#         ;
#
#
#
#
#             var marker_5e78a7fc04af0c10c139cca36ff8b34f = L.marker(
#                 [47.402830010183635, 8.49994040833819],
#                 {
# }
#             ).addTo(marker_cluster_84d835bd9c993a0cb8dc8c537dbf6723);
#
#
#         var popup_9c90b3e1241dfe6549dcda8dd009fb37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfbb3db4b792ac78808e6a15936331f7 = $(`&lt;div id=&quot;html_bfbb3db4b792ac78808e6a15936331f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tränkbrunnen Höngg&lt;/div&gt;`)[0];
#                 popup_9c90b3e1241dfe6549dcda8dd009fb37.setContent(html_bfbb3db4b792ac78808e6a15936331f7);
#
#
#
#         marker_5e78a7fc04af0c10c139cca36ff8b34f.bindPopup(popup_9c90b3e1241dfe6549dcda8dd009fb37)
#         ;
#
#
#
#
#             var marker_7f9bbb60b6766bc9f9c5a5f981a89ec7 = L.marker(
#                 [47.40216371018733, 8.49944180833675],
#                 {
# }
#             ).addTo(marker_cluster_84d835bd9c993a0cb8dc8c537dbf6723);
#
#
#             var marker_aaf1585344c906e1b8e1e14acd32bf3e = L.marker(
#                 [47.40729091017536, 8.550476408394264],
#                 {
# }
#             ).addTo(marker_cluster_84d835bd9c993a0cb8dc8c537dbf6723);
#
#
#             var marker_4e2e5cca98e99fd8f42cb252c1150793 = L.marker(
#                 [47.405301110180424, 8.503773708339574],
#                 {
# }
#             ).addTo(marker_cluster_84d835bd9c993a0cb8dc8c537dbf6723);
#
#
#             var marker_3ef218d8b9d52896214bcd360ca3e2b1 = L.marker(
#                 [47.40929161018714, 8.49485070834046],
#                 {
# }
#             ).addTo(marker_cluster_84d835bd9c993a0cb8dc8c537dbf6723);
#
#
#         var popup_7e5419a7f0bb7dc1616aa3ab0e7c39ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d1adac96cd0c879d0f1ad3e73dd037d = $(`&lt;div id=&quot;html_2d1adac96cd0c879d0f1ad3e73dd037d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brunnen zur Eingemeidung&lt;/div&gt;`)[0];
#                 popup_7e5419a7f0bb7dc1616aa3ab0e7c39ce.setContent(html_2d1adac96cd0c879d0f1ad3e73dd037d);
#
#
#
#         marker_3ef218d8b9d52896214bcd360ca3e2b1.bindPopup(popup_7e5419a7f0bb7dc1616aa3ab0e7c39ce)
#         ;
#
#
#
#
#             var marker_b83d44163f5a5f47e8313abe424f2b08 = L.marker(
#                 [47.33748811015381, 8.524711108386514],

# %% [markdown]
# ## Step 7: Export and add your map to Github
# Export the map as as an interactive HTML file:

# %%
# Save the current folium map object (m) as an interactive HTML file named "map_1.html"
# You can find it and download it under "Files"
# You can also open this file in any web browser to view the map outside of the notebook environment
m.save("map_1.html")

# %% [markdown]
# To publish your map online follow these steps:
#
# 1. **Find your HTML file** (e.g., `map_1.html`) in your Colab file panel.
# 2. **Download the HTML file** to your local computer.
# 3. **Open the file** in your web browser to view the interactive map.
# 4. **Open the same file in a text editor** (e.g., VS Code, Atom, or Notepad).
# 5. **Copy the HTML code**, then go to your GitHub repository and open your previously created `index.html` file.
# 6. **Paste the HTML code** into the `index.html`, adjust the text from the previous headings and save it (commit the changes).
#
# After a few minutes, your own web map will be update with the additional map!
#
# **Your map online website:**
# ```
# https://<your-username>.github.io/<repository-name>
# ```
#
# ---
